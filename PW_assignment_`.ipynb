# %% [markdown]
# Q.1 What is Python, and why is it popular?
#
#    - Python is a high level,interpreted programming langusage known for its easy to read syntax and versatality.It is widely used in fields such as web development, data analysis, AI, automation and many more.
#
#     It is popular because of reasons listen below
#
#     1- Python syntax is a easy and readable which is easy for begineers.
#
#     2- python is interpretend which means codes are executed line by line which makes it bug free.
#
#     3- python has extensive libraries that simplify tasks like machine learning and many more.
#
# Q.2 What is an interpreter in Python?
#
#      - An interpreter is a program that reads and execute the python code line by line, which make it easier and reliable.
#      Python code is executed directly by an interpreter in real time.
#
# Q.3  What are pre-defined keywords in Python?
#
#      -  Pre-defined keywords are special words that have a predefined meaning in the code. They cannot be used as indentifiers.
#      Some examples are as follow-False, break, continue,if, else etc.
#
# Q.4  Can keywords be used as variable names?
#
#      - NO, keywords cannot be as as variable names as they have their definate special meaning in the code.
#      EXAMPLE-- if=10.
#      if cannot be used as variable, it will show a syntax error
#
# Q.5  What is mutability in Python?
#
#     - Mutablity in python, means to edit or change the value of variable which is assigned to it when created. An object is mutable if its state or value can be changed and if it cannot be changed, then it is know as immutablity.
#
# Q.6  Why are lists mutable, but tuples are immutable?
#
#     - The reasons are as follows
#
#     1- Lists are designed to be mutable because they are designed to be dynamic collections of items that can grow and modify.They are intended to be used when the content of the collection need to change.
#
#     2- Tuples, on the other hand are designed to be static collection of item that cannot be changed. TUPLES are typically used to store data that should not be allowed to modify to save the integrity of data.
#
# Q.7 What is the difference between “==” and “is” operators in Python?
#
#     -IN python, both are comparison operator but used for different purpose.
#
#     "==" is used to check the value equality. It checks whether the value of two object are same or different.
#     Example- a=[1,2,3]
#              b=[1,2,3]
#              print(a=b)
#              OUTPUT- TRUE
#
#     "is" it is used to check the object identity. It is used to check whether the two variable are in the same memory or not.
#     Example- a=[1,2,3]
#              b=[1,2,3]
#              print(a is b)
#              Output- False
#
# Q.8  What are logical operators in Python?
#
#      - Logical operator are used to perform logical operation on boolean values(TRUE or FALSE).
#      There are 3 types
#      And, or, not
#
#      And operator returns TRUE if both the condition are TRUE else if either of the condition is FALSE then it will return FALSE.
#      EXAMPLE- x=5
#               y=10
#               if(x>3 and y<15)
#               print(result)
#               OUTPUT TRUE
#
#      Or operator will return TRUE if one condition is TRUE,only return FALSE when both the condition are FALSE.
#      EXAMPLE x=5
#              y=10
#              result=(x>3 or y<5)
#              print(result)
#              OUTPUT TRUE
#
#
# Q.9 What is type casting in Python?
#
#     - It refers to the process of converting one data type to another,this is necessary when you are working with different data types of data that need to be compatible for operation.
#
#
#
# Q.10- What is the difference between implicit and explicit type casting?
#
#       -  There are two types of Type casting
#     1- Implicit Type casting- This happens when python automatically converts the data type.
#     EXAMPLE- x=5
#              y=2.5
#              result = x+y
#              OUTPUT- 7.5
#
#     2- Explicit type casting- This happens when you manually converts one data type to another.
#     EXAMPLE- x="42"
#              y=int(x);  #converts string into onteger
#              print(y)
#              print(type(y))
#              OUTPUT- 42
#                      Class 'int'
#
# Q.11- What is the purpose of conditional statements in Python?
#
#     - The purpose of conditional statement is to allow program to make decision based on certain criteria. They also help to control the flow of operations by running certain codes only when specific conditions are not set
#
# Q.12- How does the elif statement work?
#
#     - the elif statement stands for "else-if" and is used as a part of a chain of conditional statement to check multiple conditions. It allows you to check multiple conditions at the same time.
#     EXAMPLE- x=10
#              if(x>15)
#              print(x is greater than 15)
#              elif(x>5)
#              print(x is greater than 5 but less than or equal to 15)
#              elif(x>0)
#              print(x is positive but less than or equal to 5)
#              else
#              print(x is zero or negative)
#              OOUTPUT- x is greater than 5 but less than or equal to 15
#
# Q.13 What is the difference between for and while loops?
#
#     - FOR loop- The for loop is typically used when the number of operations is know beforehand or when you want to repeat for a sequence.
#     EXAMPLE- Fruits["banana, apple, orange]
#              for Fruits in Fruits;
#              print(fruit)
#              OUTPUT-apple
#                     banana
#                     orange
#
#     - While loop- it's purpose is typically used when number of iteration is not known beforehand, and you want the loop to continue until the desirable result.
#     EXAMPLE- i=0
#              while(i<5)
#              print(i)
#              i+=1
#              OUTPUT- 0
#                      1
#                      2
#                      3
#                      4
#
# Q.14-  Describe a scenario where a while loop is more suitable than a for loop?
#
#     - Consider a scenerio where a program has to wait for specific event, such as a server connection being established. A while loop can be used to keep checking the condition until server is connected,
#     EXAMPLE- Server_connection= FALSE
#              while not Server_connection:
#              Server_connection=check the connection();
#              print(waiting for server to connect);
#              print(Server connected);

# %% [markdown]
# # New Section

# %%
# Write a Python program to print "Hello, World!?

print("Hello world")

# Write a Python program that displays your name and age?

name= "Yash"
age= 24
print(name)
print(age)

#Write code to print all the pre-defined keywords in Python using the keyword library?

import keyword
print(keyword.kwlist)

# Write a program that checks if a given word is a Python keyword?

import keyword
def is_python_keyword(word):
   return keyword.iskeyword(word)
#input from the user
word=input("enter a word to check");
if (keyword.iskeyword(word)):
    print(f"'{word}' is_python_keyword.")
else:
    print(f"'{word}' is not a keyword.")

#Create a list and tuple in Python, and demonstrate how attempting to change an element works differently
#for each?

#creating a list
my_list = [10, 20, 30, 40]
  #attempt to change an element
print("original list", my_list)
my_list[2] = 100
print("Modified list", my_list)

#creating a tuple
my_tuple = {10, 20, 30, 40}
#attempt to modify
print("original tuple", my_tuple)
#my_tuple[2] = {100}  #it will show an error as tuple cannot be modified
#print("Modified tuple", my_tuple)

#Write a function to demonstrate the behavior of mutable and immutable arguments?

def mutable_immutable(ar):
 y =5
 print(f"Original value of y (immutable): {y}")
 y += 6
 print(f"modified value of y (immutable):{y}")

#Write a function to demonstrate the behavior of mutable and immutable arguments?

def mutable_immutable(ar):
 y =5
 print(f"Original value of y (immutable): {y}")
 y += 6
 print(f"modified value of y (immutable):{y}")

#Write a program to demonstrate the use of logical operators?

x = 10
y = 5
#using "and" operator
print(f"x = {x}, y = {y}")
print(f"x > 5 and y < 10: {x > 5 and y < 10}")

#usimg "or" operator
print(f"x = {x}, y = {y}")
print(f"x > 15 or y < 10: {x > 15 or y < 10}")

#using "not" operator
print(f"x = {x}, y = {y}")
print(f"not (x > 5): {not (x > 5)}")

a = True
b = False
print(f"a = {a}, b = {b}")
print(f"a and b: {a and b}")
print(f"a or b: {a or b}")
print(f"not a: {not a}")

#Write a Python program to convert user input from string to integer, float, and boolean types?

user_input = input("enter a value:")

# conveting into integer
try:
 int_value = int(user_input)
 print(f"integer value: {int_value}")
 print(type(int_value))
except:
  print("Invalid input. Please enter a valid integer.")

#converting to float
try:
 float_value = float(user_input)
 print(f"float value: {float_value}")
 print(type(float_value))
except:
  print("Invalid input. Please enter a valid float.")

#converting to boolean
boolean_value = bool(user_input)
print(f"boolean value: {boolean_value}")

#Write code to demonstrate type casting with list elements?

string_list = ["1", "2", "3", "4.5", "True"]
int_list = [int(item) if item.isdigit() else item for item in string_list]
print("converted to integer:", int_list)

float_list = [float(item) if item.replace('.', '', 1).isdigit() else item for item in string_list]
print("conveted to float:", float_list)

boolean_list = [bool(item) if item.lower() in ['true', 'false'] else item for item in string_list]
print("converted to boolean:", boolean_list)

# Write a program that checks if a number is positive, negative, or zero?

num = float(input("enter a number:"))
if num > 0:
  print("positive number")
elif num < 0:
  print("negative number")
else:
  print("zero")

# Write a for loop to print numbers from 1 to 10?

for i in range(1,11):
  print(i)

# Write a Python program to find the sum of all even numbers between 1 and 50?

sum_even = 0
for num in range(1,51):
  if num%2 == 0:
   sum_even += num
print("sum of even numbers between 1 and 50:", sum_even)

# Write a program to reverse a string using a while loop?

input_string = input("enter a string:")
reversed_string = ""
length = len(input_string)
index = length - 1
while index >= 0:
  reversed_string += input_string[index]
  index -= 1
print("reversed string:", reversed_string)

# Write a Python program to calculate the factorial of a number provided by the user using a while loop.?

num = int(input("enter a number:"))
factorial = 1
current = 1
while current <= num:
  factorial *= current
  current += 1
print(f"factorial of {num} is {factorial}")
# Out:
# Hello world
# Yash
# 24
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
# enter a word to checkasd
# 'asd' is not a keyword.
# original list [10, 20, 30, 40]
# Modified list [10, 20, 100, 40]
# original tuple {40, 10, 20, 30}
# x = 10, y = 5
# x > 5 and y < 10: True
# x = 10, y = 5
# x > 15 or y < 10: True
# x = 10, y = 5
# not (x > 5): False
# a = True, b = False
# a and b: False
# a or b: True
# not a: False
# enter a value:sad
# Invalid input. Please enter a valid integer.
# Invalid input. Please enter a valid float.
# boolean value: True
# converted to integer: [1, 2, 3, '4.5', 'True']
# conveted to float: [1.0, 2.0, 3.0, 4.5, 'True']
# converted to boolean: ['1', '2', '3', '4.5', True]
# enter a number:3
# positive number
# 1
# 2
# ...
